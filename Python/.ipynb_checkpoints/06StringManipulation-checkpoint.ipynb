# %%
name = 'Sara Devi'

print(name, type(name))
# Out:
# Sara Devi <class 'str'>

# %%
college = "St Joseph's, Trichy"

print(college, type(college))
# Out:
# St Joseph's, Trichy <class 'str'>

# %%
para = '''India, officially the Republic of India, is a vast, diverse, 
and ancient civilization in South Asia, characterized by its "unity in diversity" with numerous cultures,
languages, and religions coexisting. It is the world's largest democracy, the seventh-largest country by area, 
and has the second-largest population. Bordered by the Himalayas in the north and surrounded by the Indian Ocean, 
Bay of Bengal, and Arabian Sea, it boasts a varied geography.'''

print(para)
# Out:
# India, officially the Republic of India, is a vast, diverse,
# and ancient civilization in South Asia, characterized by its "unity in diversity" with numerous cultures,
# languages, and religions coexisting. It is the world's largest democracy, the seventh-largest country by area,
# and has the second-largest population. Bordered by the Himalayas in the north and surrounded by the Indian Ocean,
# Bay of Bengal, and Arabian Sea, it boasts a varied geography.

# %% [markdown]
# # String Manipulation :

# %%
msg = 'Hi Welcome Python'

print(msg)
# Out:
# Hi Welcome Python

# %%
print(msg[1])
# Out:
# i

# %%
v1 = msg[0:1 + 1]

print(v1)
# Out:
# Hi

# %%
print(msg[3:10])
# Out:
# Welcome

# %%
print(msg[0:1 + 1], msg[11:17])
# Out:
# Hi Python

# %%
print(msg[:10])
# Out:
# Hi Welcome

# %%
print(msg[11:])
# Out:
# Python

# %%
print(msg[3:10])
# Out:
# Welcome

# %%
print(msg[-14:-7])
# Out:
# Welcome
