# %%
print('Welcome Python!..')
# Out:
# Welcome Python!..

# %%
print(10 + 20)
# Out:
# 30

# %%
# Single Line Comment

'''
Multi 
Line 
Comment!....
'''

print('Single & Multi Line Comment')
# Out:
# Single & Multi Line Comment

# %% [markdown]
# # Data Types
# ------------

# %% [markdown]
# int - 0 to 9
#
# float  - 10.5,...
#
# str - '' or "" used for a to z, A to Z, Special Characters(!@#$%^&*()), numbers
#
# bool - True, False

# %% [markdown]
# # Variable

# %%
userName = 'Sara'

age = 25

avg = 90.5

married = True

print(userName, type(userName))

print(age, type(age))

print(avg, type(avg))

print(married, type(married))
# Out:
# Sara <class 'str'>
# 25 <class 'int'>
# 90.5 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# # Concatination Operator(,)

# %%
print('User Name : ', userName)
# Out:
# User Name :  Sara

# %%
print('User Name : ', userName, ' Age is ', age)
# Out:
# User Name :  Sara  Age is  25

# %%
print('User Name : ' + userName, ' Age is ', age)
# Out:
# User Name : Sara  Age is  25

# %% [markdown]
# # Type Casting

# %%
print('User Name : ' + userName, ' Age is ' + str(age))
# Out:
# User Name : Sara  Age is 25

# %% [markdown]
# # Python Inputs

# %%
name = input('Enter your Name : ')

age = int(input('Enter your Age : '))

print('-----------------------------------------------')

print(name, ' your age is ', age)

birth_year = 2026 - age

print('Birth year is : ', birth_year)
# Out:
# Enter your Name :  Sara
# Enter your Age :  23
# -----------------------------------------------
# Sara  your age is  23
# Birth year is :  2003
